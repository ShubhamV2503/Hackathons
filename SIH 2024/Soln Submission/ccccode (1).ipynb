# %% [markdown]
# ## Fuzzy Name conversion of Names in Police Records
#
#
# #### 1.  Advanced Fuzzy Matching and Phonetic Search for Accurate Name Retrieval
# #### 2. Standardized Transliteration and Error Correction Mechanisms
# #### 3. Script Interoperability and Best Practices for Data Entry

# %%
# !pip install python-Levenshtein
# !pip install fuzzywuzzy

# %%
import os ,sys
import numpy as np

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import Levenshtein

# %%
df  = pd.read_csv('dd.csv')

# %%
df.head()
# Out:
#      Name
# 0   Anjal
# 1  Anrali
# 2  Anjali
# 3   jrjun
# 4  Anjali

# %%
df.drop_duplicates(inplace=True)

# %%
df['Name'].unique()
# Out:
# array(['Anjal', 'Anrali', 'Anjali', ..., 'Anfali', 'zavita', 'Rajegsh'],
#       dtype=object)

# %%
TfidfVectorizer
# Out:
# sklearn.feature_extraction.text.TfidfVectorizer

# %%
def find_similar_names(names_list, target_name, threshold=0.2):
    vectorizer = TfidfVectorizer()
    
    vectorizer.fit(names_list)
    
    vectors = vectorizer.transform(names_list).toarray()

    target_vector = vectorizer.transform([target_name]).toarray()

    cosine_similarities = cosine_similarity(target_vector, vectors).flatten()

    similar_names = [name for name, similarity in zip(names_list, cosine_similarities) if similarity >= threshold]

    return similar_names

# %%
df.shape
# Out:
# (1930, 1)

# %%
names = list(df['Name'])

# %%
names
# Out:
# ['Anjal',
#  'Anrali',
#  'Anjali',
#  'jrjun',
#  'Surj',
#  'Arjun',
#  'Kavita',
#  'Rajesh',
#  'Ramesh',
#  'Anjalhi',
#  'Suraj',
#  'Arjrun',
#  'Suesh',
#  'Ramsh',
#  'Amit',
#  'Suresh',
#  'Rjesh',
#  'Arjum',
#  'kNeha',
#  'Priya',
#  'Awit',
#  'Anjai',
#  'Arjn',
#  'Rajesn',
#  'vmit',
#  'Rajosh',
#  'Ahrjun',
#  'Suressh',
#  'Sura',
#  'Rajeh',
#  'Sburesh',
#  'Suresr',
#  'Arun',
#  'Ravesh',
#  'Armit',
#  'Neha',
#  'Nea',
#  'Rqajesh',
#  'Priyra',
#  'Ajali',
#  'Sburaj',
#  'Ragesh',
#  'Priyga',
#  'Amik',
#  'eha',
#  'Kavitg',
#  'Kavitp',
#  'samesh',
#  'Sursh',
#  'Kavta',
#  'Prlya',
#  'Suryaj',
#  'Arjkn',
#  'Amt',
#  'Anjaoli',
#  'Sureuh',
#  'Rajrsh',
#  'Suwesh',
#  'Nha',
#  'Ami',
#  'Rajessh',
#  'Kavqita',
#  'nNeha',
#  'mit',
#  'Sukaj',
#  'Kavith',
#  'Priyya',
#  'Aujali',
#  'ravita',
#  'Kavit',
#  'Anjalo',
#  'Rajevsh',
#  'Ait',
#  'uresh',
#  'Priy',
#  'Prriya',
#  'Rjajesh',
#  'Rmesh',
#  'Priyo',
#  'Anali',
#  'sSuraj',
#  'Kaita',
#  'Artjun',
#  'Ngeha',
#  'Agit',
#  'rjun',
#  'Surxsh',
#  'Ngha',
#  'Rajesth',
#  'tAmit',
#  'Amidt',
#  'Sraj',
#  'Kmvita',
#  'Rramesh',
#  'Kavia',
#  'Ramedh',
#  'cKavita',
#  'rRajesh',
#  'Sures',
#  'Kavitaa',
#  'Raesh',
#  'znjali',
#  'Pria',
#  'qSuraj',
#  'Arjuxn',
#  'Rameph',
#  'Prilya',
#  'Prhya',
#  'Sbresh',
#  'nSuraj',
#  'Kavitda',
#  'Kalvita',
#  'qNeha',
#  'Neh',
#  'Ayrjun',
#  'avita',
#  'Sluresh',
#  'Kavitea',
#  'Racjesh',
#  'Ajun',
#  'Priye',
#  'Rasjesh',
#  'Rakesh',
#  'Suwraj',
#  'Arqjun',
#  'Prwya',
#  'meha',
#  'Anjalsi',
#  'Priwa',
#  'lArjun',
#  'Suaj',
#  'Ahjun',
#  'Arjur',
#  'Surmsh',
#  'Abjun',
#  'Rajesch',
#  'furaj',
#  'Anjtali',
#  'nAmit',
#  'Nehpa',
#  'aRamesh',
#  'Ramemsh',
#  'brjun',
#  'bArjun',
#  'Rajemh',
#  'amesh',
#  'Arjutn',
#  'Anjalf',
#  'iRamesh',
#  'Piya',
#  'Ralesh',
#  'Anjsli',
#  'ajesh',
#  'Rhamesh',
#  'Anjarli',
#  'Kavirta',
#  'Kavcta',
#  'Susesh',
#  'uraj',
#  'Sursj',
#  'Nehua',
#  'Nehca',
#  'Anjli',
#  'Arju',
#  'Rajesrh',
#  'Sresh',
#  'Nuha',
#  'Arjuy',
#  'Rajsh',
#  'Anjyli',
#  'tnjali',
#  'Kavitl',
#  'lAnjali',
#  'Ahit',
#  'Amiyt',
#  'Ktvita',
#  'Prqiya',
#  'Surafj',
#  'Kagita',
#  'Kavwita',
#  'Kavvta',
#  'luraj',
#  'Kaviwta',
#  'Siuraj',
#  'Arjuin',
#  'iNeha',
#  'jRamesh',
#  'eAmit',
#  'Rujesh',
#  'ueha',
#  'Rjamesh',
#  'Rajbesh',
#  'yRamesh',
#  'Prizya',
#  'Suqesh',
#  'fSuresh',
#  'Surapj',
#  'Ravjesh',
#  'Rajesq',
#  'Surksh',
#  'Surhesh',
#  'hriya',
#  'Aunjali',
#  'Arwjun',
#  'Nevha',
#  'Nehha',
#  'aKavita',
#  'Ramesah',
#  'Amist',
#  'Rajesx',
#  'Rajuesh',
#  'mArjun',
#  'Prya',
#  'hrjun',
#  'Straj',
#  'Nzha',
#  'hnjali',
#  'eSuraj',
#  'jArjun',
#  'tNeha',
#  'Apmit',
#  'Kavifta',
#  'Nehj',
#  'Sudaj',
#  'Sureh',
#  'Sturaj',
#  'Rajzsh',
#  'Arjtn',
#  'Ramelsh',
#  'Sfraj',
#  'Aamit',
#  'kmit',
#  'Ramebsh',
#  'Rameth',
#  'Priysa',
#  'Rajecsh',
#  'Anjalg',
#  'Priyb',
#  'Amdit',
#  'Surmj',
#  'Nehm',
#  'mNeha',
#  'Praiya',
#  'wNeha',
#  'Kavitwa',
#  'Kvita',
#  'Anjalh',
#  'Priza',
#  'Suruj',
#  'Sujraj',
#  'Surehsh',
#  'Rajeph',
#  'Rdajesh',
#  'Aqjali',
#  'jAnjali',
#  'Prila',
#  'Amib',
#  'Amio',
#  'Amif',
#  'iSuraj',
#  'Rajes',
#  'Nehma',
#  'Priyl',
#  'ruresh',
#  'Sureoh',
#  'ouraj',
#  'Nezha',
#  'Radmesh',
#  'Kwvita',
#  'Pruya',
#  'Arjupn',
#  'Rqmesh',
#  'Avnjali',
#  'qeha',
#  'Kavitfa',
#  'Rmjesh',
#  'Arjuon',
#  'reha',
#  'Rajewh',
#  'kuraj',
#  'Acrjun',
#  'Ramehsh',
#  'Rasesh',
#  'Sruresh',
#  'Ramsesh',
#  'Raxesh',
#  'Suuesh',
#  'Suxraj',
#  'Ancjali',
#  'Suiaj',
#  'Remesh',
#  'Sutaj',
#  'Surlaj',
#  'zRamesh',
#  'Rbmesh',
#  'Ramesph',
#  'srjun',
#  'Nehq',
#  'Rambesh',
#  'Anjalyi',
#  'Nehk',
#  'Aryun',
#  'Sutresh',
#  'mavita',
#  'Ramvsh',
#  'Arejun',
#  'Rayjesh',
#  'Priyha',
#  'Priyba',
#  'Ramresh',
#  'Khvita',
#  'Adjun',
#  'Ncha',
#  'Soresh',
#  'Arjux',
#  'Surazj',
#  'Amrjun',
#  'Kavitia',
#  'injali',
#  'Prieya',
#  'Sfuresh',
#  'Amot',
#  'Amiq',
#  'Araun',
#  'Aqjun',
#  'Kavitu',
#  'Supaj',
#  'Arjsn',
#  'Shresh',
#  'Arvun',
#  'bNeha',
#  'Rajesb',
#  'curaj',
#  'pAnjali',
#  'tSuraj',
#  'Avjali',
#  'Surqsh',
#  'prjun',
#  'Ayjali',
#  'Auit',
#  'Kavioa',
#  'riya',
#  'Surai',
#  'Arjsun',
#  'Suresvh',
#  'Sqraj',
#  'Sugaj',
#  'Rames',
#  'Nefha',
#  'Arpjun',
#  'Suraz',
#  'Prfya',
#  'uuresh',
#  'Nieha',
#  'Anjpali',
#  'Rajaesh',
#  'Rajeush',
#  'Suiraj',
#  'Nexa',
#  'Squresh',
#  'fArjun',
#  'orjun',
#  'Amet',
#  'Souresh',
#  'Suresf',
#  'Arjunn',
#  'Amht',
#  'Racesh',
#  'nrjun',
#  'Amjit',
#  'Suuraj',
#  'wAnjali',
#  'Atmit',
#  'hNeha',
#  'Nesa',
#  'oeha',
#  'Rajysh',
#  'Newha',
#  'Prcya',
#  'Anjxli',
#  'Aeit',
#  'Atjun',
#  'Apit',
#  'Nehp',
#  'Aojun',
#  'aeha',
#  'Swresh',
#  'Suresu',
#  'Anjhli',
#  'Anvali',
#  'Arjufn',
#  'Rajesnh',
#  'Priyx',
#  'Amzit',
#  'Pqriya',
#  'Syuresh',
#  'gKavita',
#  'Ramess',
#  'bAmit',
#  'sAmit',
#  'Akit',
#  'Arfun',
#  'Anjaly',
#  'Kawita',
#  'Surao',
#  'Rajhsh',
#  'Syraj',
#  'Ratmesh',
#  'Arjuq',
#  'Azjun',
#  'Rbajesh',
#  'Priyfa',
#  'gAmit',
#  'tAnjali',
#  'veha',
#  'Rarjesh',
#  'Raymesh',
#  'Surkaj',
#  'Suvraj',
#  'Ramesm',
#  'Nueha',
#  'Priyda',
#  'Kaovita',
#  'Arzjun',
#  'Nela',
#  'Anjahi',
#  'Prviya',
#  'eSuresh',
#  'Nelha',
#  'nPriya',
#  'Sunesh',
#  'juraj',
#  'Ramelh',
#  'Radesh',
#  'Rajesc',
#  'Nkeha',
#  'Anjqali',
#  'Prbya',
#  'Rajech',
#  'tArjun',
#  'Surexsh',
#  'Kwavita',
#  'Acit',
#  'Arjup',
#  'Ranesh',
#  'Kaviita',
#  'Nehs',
#  'Surpj',
#  'Suray',
#  'Surahj',
#  'Suresd',
#  'Kavcita',
#  'Snresh',
#  'Rqamesh',
#  'Surzesh',
#  'Rymesh',
#  'Rameqh',
#  'Kavnita',
#  'Periya',
#  'Amix',
#  'Priaya',
#  'Rajebsh',
#  'Suzaj',
#  'Aroun',
#  'Surdj',
#  'Neqa',
#  'Suram',
#  'jamesh',
#  'Nqha',
#  'Rajesih',
#  'Priywa',
#  'Sureslh',
#  'Rajesuh',
#  'Ramnsh',
#  'Priiya',
#  'fajesh',
#  'tavita',
#  'Kavika',
#  'Sulaj',
#  'Surash',
#  'Anjbali',
#  'Rafesh',
#  'Argjun',
#  'Surfesh',
#  'Prxya',
#  'Asjun',
#  'oAmit',
#  'dAmit',
#  'Aljun',
#  'Armjun',
#  'Amgit',
#  'Suraqj',
#  'Kavigta',
#  'Kdavita',
#  'Surtsh',
#  'Arjumn',
#  'tRajesh',
#  'Arxjun',
#  'Priym',
#  'Akjun',
#  'Amsit',
#  'Arjgn',
#  'Arjuvn',
#  'pavita',
#  'Prisa',
#  'Anmjali',
#  'Kavvita',
#  'Anqali',
#  'Priyv',
#  'Surepsh',
#  'Arjpn',
#  'Amyit',
#  'Kavifa',
#  'Sxraj',
#  'Kavira',
#  'Kafvita',
#  'vAmit',
#  'mriya',
#  'Surefsh',
#  'lmit',
#  'Neta',
#  'vuresh',
#  'Prsya',
#  'Rameh',
#  'Rauesh',
#  'sRamesh',
#  'oArjun',
#  'Aqnjali',
#  'Rajesqh',
#  'Aomit',
#  'Aneali',
#  'Arjhun',
#  'cnjali',
#  'gavita',
#  'Ramech',
#  'Amic',
#  'Anjagi',
#  'Ayit',
#  'Anjalpi',
#  'Suralj',
#  'Pridya',
#  'Surcj',
#  'Amjali',
#  'Rtamesh',
#  'Kavitx',
#  'Ramersh',
#  'Ancali',
#  'vSuraj',
#  'Anjalbi',
#  'Nehia',
#  'Rameah',
#  'Poriya',
#  'Ramjesh',
#  'Suresph',
#  'Netha',
#  'hAmit',
#  'Kavmta',
#  'havita',
#  'Suraij',
#  'cNeha',
#  'iuresh',
#  'briya',
#  'Anjazli',
#  'Surevh',
#  'Rajdesh',
#  'Kavisa',
#  'Rameyh',
#  'Sudresh',
#  'Razesh',
#  'Anjjali',
#  'sSuresh',
#  'qrjun',
#  'Rajeqh',
#  'Soraj',
#  'Surqaj',
#  'yrjun',
#  'Rajedsh',
#  'Kxvita',
#  'Ankjali',
#  'Anjbli',
#  'Priyua',
#  'Surdesh',
#  'Kfavita',
#  'lSuraj',
#  'Arjuu',
#  'Niha',
#  'Ramoesh',
#  'Prika',
#  'Raajesh',
#  'Surwesh',
#  'Sufresh',
#  'Arjcun',
#  'Anjalc',
#  'Pziya',
#  'Kavoita',
#  'Prjiya',
#  'Axrjun',
#  'njali',
#  'Amift',
#  'dNeha',
#  'Kavlita',
#  'Karvita',
#  'Sufraj',
#  'Aijun',
#  'Amigt',
#  'Rajresh',
#  'bSuraj',
#  'Ahjali',
#  'nriya',
#  'Surebsh',
#  'Nehfa',
#  'Prciya',
#  'Seresh',
#  'Ramesih',
#  'Nfeha',
#  'Rafjesh',
#  'Suqresh',
#  'Surayj',
#  'Surekh',
#  'Ramhsh',
#  'oRajesh',
#  'qAnjali',
#  'Suaresh',
#  'Rajesz',
#  'Artun',
#  'Nehga',
#  'Suresi',
#  'Sujesh',
#  'Rnamesh',
#  'Surauj',
#  'Surrsh',
#  'Kavxita',
#  'Rajyesh',
#  'Surac',
#  'Rammesh',
#  'Nehea',
#  'amit',
#  'Nehv',
#  'Kazita',
#  'Nyha',
#  'Akrjun',
#  'Sduresh',
#  'Amrit',
#  'Ramesk',
#  'Raqesh',
#  'Suresj',
#  'Rajesxh',
#  'Kdvita',
#  'Pariya',
#  'Surav',
#  'Amqit',
#  'Anjazi',
#  'Svuraj',
#  'Surwsh',
#  'cSuresh',
#  'Neya',
#  'Arjug',
#  'Rlajesh',
#  'Proya',
#  'Anwjali',
#  'Amst',
#  'Sureush',
#  'Rajmsh',
#  'Rfajesh',
#  'Arjua',
#  'Surakj',
#  'oPriya',
#  'uamesh',
#  'Anjalt',
#  'Rajvesh',
#  'Prliya',
#  'Surhj',
#  'Amil',
#  'Ramesr',
#  'Rajkesh',
#  'Atnjali',
#  'Anjmali',
#  'yArjun',
#  'Anhjali',
#  'Anjfli',
#  'turesh',
#  'Suhraj',
#  'Kavdita',
#  'lKavita',
#  'Surbaj',
#  'Reamesh',
#  'Arjjun',
#  'Rajeosh',
#  'Pribya',
#  'Swuraj',
#  'Arwun',
#  'Raemesh',
#  'Pnriya',
#  'Kavitpa',
#  'Atjali',
#  'Amiot',
#  'wSuraj',
#  'Priyz',
#  'Rammsh',
#  'Rajeso',
#  'Arjuv',
#  'pmit',
#  'Anojali',
#  'Ralmesh',
#  'Anjapli',
#  'bajesh',
#  'Sureqh',
#  'Scresh',
#  'Amia',
#  'Abjali',
#  'Katita',
#  'Nena',
#  'Nehba',
#  'Puiya',
#  'Ariun',
#  'nuraj',
#  'Kasvita',
#  'mRamesh',
#  'zAnjali',
#  'Priys',
#  'Agjun',
#  'Prixa',
#  'Arjtun',
#  'Sumesh',
#  'Axit',
#  'Priyqa',
#  'Amiu',
#  'Rameoh',
#  'Kzavita',
#  'Katvita',
#  'wKavita',
#  'Priuya',
#  'Anjalx',
#  'Ramesoh',
#  'Rameqsh',
#  'Subresh',
#  'Surjesh',
#  'keha',
#  'Arsun',
#  'Rzjesh',
#  'rNeha',
#  'vuraj',
#  'Anjabli',
#  'Smuresh',
#  'Arjnn',
#  'fSuraj',
#  'Suraf',
#  'Surasj',
#  'yajesh',
#  'Priaa',
#  'uSuresh',
#  'qmit',
#  'Nekha',
#  'Supresh',
#  'Nweha',
#  'Nhha',
#  'Sugraj',
#  'zriya',
#  'Aryjun',
#  'Neia',
#  'frjun',
#  'Anjadli',
#  'Ramexh',
#  'Nehy',
#  'Kavuita',
#  'Surej',
#  'Nehc',
#  'Sucaj',
#  'Prniya',
#  'Asit',
#  'Ramfsh',
#  'Nepha',
#  'Sdresh',
#  'Pritya',
#  'Surmaj',
#  'Surhaj',
#  'Pripya',
#  'Raamesh',
#  'Rxamesh',
#  'Prxiya',
#  'Amiit',
#  'Pvriya',
#  'aNeha',
#  'Amiut',
#  'Arjkun',
#  'Rameseh',
#  'Afit',
#  'Suragj',
#  'Amiy',
#  'Kqvita',
#  'aSuresh',
#  'Arjuk',
#  'Rajoesh',
#  'Sural',
#  'Sugesh',
#  'cajesh',
#  'Subaj',
#  'arjun',
#  'Anjeali',
#  'Adrjun',
#  'Anjalii',
#  'Kpvita',
#  'Suhesh',
#  'Anoali',
#  'Przya',
#  'gNeha',
#  'lamesh',
#  'Nehx',
#  'Armun',
#  'Anjalwi',
#  'Surfj',
#  'Amis',
#  'Arjuo',
#  'Kavicta',
#  'xAnjali',
#  'Arjugn',
#  'Anjalgi',
#  'Rameesh',
#  'Amict',
#  'Amiwt',
#  'Prmya',
#  'Amvt',
#  'Surlj',
#  'Aenjali',
#  'Anjalti',
#  'Prgya',
#  'Amait',
#  'Priba',
#  'lrjun',
#  'Prikya',
#  'Nqeha',
#  'cSuraj',
#  'Kavitoa',
#  'Aqmit',
#  'Arjgun',
#  'Pdiya',
#  'muraj',
#  'Sugresh',
#  'hArjun',
#  'Nvha',
#  'Pxriya',
#  'Prica',
#  'Suzresh',
#  'Arzun',
#  'Rajeksh',
#  'Spraj',
#  'Seuraj',
#  'Surdsh',
#  'Anjdli',
#  'Nehf',
#  'Arjmn',
#  'Ajrjun',
#  'Areun',
#  'Kavitga',
#  'Rajxesh',
#  'nRamesh',
#  'Arrjun',
#  'Priyt',
#  'eavita',
#  'emit',
#  'Raxjesh',
#  'Rkmesh',
#  'qnjali',
#  'wuraj',
#  'Ramefh',
#  'criya',
#  'sKavita',
#  'Amtit',
#  'Snuresh',
#  'Arijun',
#  'Nera',
#  'Ramesmh',
#  'weha',
#  'Suoresh',
#  'Suran',
#  'Suyresh',
#  'Surgesh',
#  'Rajezsh',
#  'Suriaj',
#  'Arjuc',
#  'Surbsh',
#  'Aait',
#  'Sureysh',
#  'Arjnun',
#  'jNeha',
#  'Arhjun',
#  'Anmit',
#  'Rgjesh',
#  'Prtiya',
#  'Rajesw',
#  'peha',
#  'Kavite',
#  'iavita',
#  'Prida',
#  'Suyaj',
#  'Priypa',
#  'Rajpesh',
#  'Noeha',
#  'Rvamesh',
#  'xNeha',
#  'Nbha',
#  'Prifa',
#  'Rmamesh',
#  'xRajesh',
#  'Priyw',
#  'Kaviqa',
#  'Amimt',
#  'friya',
#  'Sunresh',
#  'sNeha',
#  'Aynjali',
#  'Seraj',
#  'Kawvita',
#  'Ssresh',
#  'Sudesh',
#  'Suresch',
#  'Priyja',
#  'Rajedh',
#  'Anjvali',
#  'yRajesh',
#  'Anejali',
#  'vPriya',
#  'Anjlli',
#  'Anjawi',
#  'Suresrh',
#  'Ramesz',
#  'Atit',
#  'Rabesh',
#  'Rajeszh',
#  'Ramzsh',
#  'Kaviuta',
#  'Kavitj',
#  'quresh',
#  'Ptriya',
#  'Kaavita',
#  'Priyd',
#  'Suxesh',
#  'zKavita',
#  'Suroj',
#  'Amqt',
#  'iPriya',
#  'cavita',
#  'Kavixta',
#  'hajesh',
#  'Susaj',
#  'Pyriya',
#  'Anjalqi',
#  'Ankali',
#  'Sturesh',
#  'Aejun',
#  'Kavitf',
#  'Rajetsh',
#  'Nehya',
#  'guraj',
#  'Kahita',
#  'Suras',
#  'Neva',
#  'kAmit',
#  'Aumit',
#  'Pzriya',
#  'Surecsh',
#  'Neea',
#  'Arjucn',
#  'Surax',
#  'Kavitqa',
#  'Pbriya',
#  'Priga',
#  'wavita',
#  'Suracj',
#  'Acmit',
#  'Ammt',
#  'Aymit',
#  'Ramezsh',
#  'Kjavita',
#  'Anjkali',
#  'Anjalr',
#  'Arjus',
#  'Rajelsh',
#  'Survesh',
#  'Amiz',
#  'heha',
#  'Anjaai',
#  'Kavnta',
#  'Pbiya',
#  'Anjatli',
#  'Awrjun',
#  'aAmit',
#  'Suhaj',
#  'Sfuraj',
#  'Anjapi',
#  'navita',
#  'Kavyita',
#  'Anjakli',
#  'Kavitc',
#  'Rfjesh',
#  'xSuresh',
#  'Arjzn',
#  'Anjyali',
#  'Sguresh',
#  'Kavdta',
#  ...]

# %%
target = "suraj"
similar_names = find_similar_names(names, target, threshold=0.5)

print(f"Names similar to '{target}': {similar_names}")
# Out:
# Names similar to 'suraj': ['Suraj', 'suraj']

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from fuzzywuzzy import process

def find_similar_names(names_list, target_name, threshold=10):
    similar_names = process.extract(target_name, names_list, limit=None, scorer=process.fuzz.token_set_ratio)
    
    return [name for name, score in similar_names if score >= threshold]

names = names
target = 'sooraj' 
similar_names = find_similar_names(names, target, threshold=10)

print(f"Names similar to '{target}': {similar_names}")
# Out:
# %%
def find_top_similar_names_levenshtein(names_list, target_name, top_n=10):
    name_distances = [(name, Levenshtein.distance(name, target_name)) for name in names_list]
    
    name_distances.sort(key=lambda x: x[1])
    
    top_matches = [name for name, distance in name_distances[:top_n]]
    
    return top_matches

# %%
names = names
target = 'Svuraj'  
similar_names = find_top_similar_names_levenshtein(names, target)

print(f"Names similar to '{target}': {similar_names}")
# Out:
# Names similar to 'Svuraj': ['Svuraj', 'Suraj', 'Sburaj', 'Siuraj', 'Sturaj', 'Suuraj', 'Swuraj', 'vuraj', 'Seuraj', 'Sfuraj']

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.26.0-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.26.0 (from python-Levenshtein)
#   Downloading levenshtein-0.26.0-cp311-cp311-win_amd64.whl (98 kB)
#                                               0.0/98.5 kB ? eta -:--:--
#      ----                                     10.2/98.5 kB ? eta -:--:--
#      ---------------                        41.0/98.5 kB 487.6 kB/s eta 0:00:01
#      ---------------                        41.0/98.5 kB 487.6 kB/s eta 0:00:01
#      ---------------                        41.0/98.5 kB 487.6 kB/s eta 0:00:01
#      ---------------                        41.0/98.5 kB 487.6 kB/s eta 0:00:01
#      ---------------                        41.0/98.5 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 98.5/98.5 kB 314.1 kB/s eta 0:00:00
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\mayank\anaconda3\lib\site-packages (from Levenshtein==0.26.0->python-Levenshtein) (3.9.1)
# Installing collected packages: Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.26.0 python-Levenshtein-0.26.0

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in c:\users\mayank\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\mayank\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: boto3 in c:\users\mayank\anaconda3\lib\site-packages (from transformers) (1.24.28)
# Requirement already satisfied: requests in c:\users\mayank\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\mayank\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex in c:\users\mayank\anaconda3\lib\site-packages (from transformers) (2023.12.25)
# Collecting sentencepiece (from transformers)
#   Downloading sentencepiece-0.2.0-cp311-cp311-win_amd64.whl (991 kB)
#                                               0.0/991.5 kB ? eta -:--:--
#                                               10.2/991.5 kB ? eta -:--:--
#                                               10.2/991.5 kB ? eta -:--:--
#      -                                     30.7/991.5 kB 220.2 kB/s eta 0:00:05
#      -                                     41.0/991.5 kB 196.9 kB/s eta 0:00:05
#      -                                     41.0/991.5 kB 196.9 kB/s eta 0:00:05
#      --                                    61.4/991.5 kB 218.8 kB/s eta 0:00:05
#      --                                    61.4/991.5 kB 218.8 kB/s eta 0:00:05
#      --                                    71.7/991.5 kB 187.3 kB/s eta 0:00:05
#      ---                                   92.2/991.5 kB 201.8 kB/s eta 0:00:05
#      ---                                   92.2/991.5 kB 201.8 kB/s eta 0:00:05
#      ----                                 112.6/991.5 kB 226.0 kB/s eta 0:00:04
#      ----                                 122.9/991.5 kB 212.1 kB/s eta 0:00:05
#      ----                                 122.9/991.5 kB 212.1 kB/s eta 0:00:05
#      -----                                143.4/991.5 kB 218.6 kB/s eta 0:00:04
#      -----                                153.6/991.5 kB 208.7 kB/s eta 0:00:05
#      -----                                153.6/991.5 kB 208.7 kB/s eta 0:00:05
#      -----                                153.6/991.5 kB 208.7 kB/s eta 0:00:05
#      -----                                153.6/991.5 kB 208.7 kB/s eta 0:00:05
#      -----                                153.6/991.5 kB 208.7 kB/s eta 0:00:05
#      ------------------------             686.1/991.5 kB 237.7 kB/s eta 0:00:02
#      ------------------------             686.1/991.5 kB 237.7 kB/s eta 0:00:02
#      -------------------------            696.3/991.5 kB 234.8 kB/s eta 0:00:02
#      --------------------------           716.8/991.5 kB 238.1 kB/s eta 0:00:02
#      --------------------------           716.8/991.5 kB 238.1 kB/s eta 0:00:02
#      --------------------------           727.0/991.5 kB 234.1 kB/s eta 0:00:02
#      --------------------------           727.0/991.5 kB 234.1 kB/s eta 0:00:02
#      --------------------------           727.0/991.5 kB 234.1 kB/s eta 0:00:02
#      --------------------------           727.0/991.5 kB 234.1 kB/s eta 0:00:02
#      --------------------------           727.0/991.5 kB 234.1 kB/s eta 0:00:02
#      ----------------------------         778.2/991.5 kB 231.9 kB/s eta 0:00:01
#      ----------------------------         798.7/991.5 kB 234.7 kB/s eta 0:00:01
#      -----------------------------        809.0/991.5 kB 236.7 kB/s eta 0:00:01
#      ------------------------------       829.4/991.5 kB 238.3 kB/s eta 0:00:01
#      ------------------------------       849.9/991.5 kB 241.0 kB/s eta 0:00:01
#      -------------------------------      870.4/991.5 kB 243.6 kB/s eta 0:00:01
#      -------------------------------      880.6/991.5 kB 241.2 kB/s eta 0:00:01
#      --------------------------------     901.1/991.5 kB 243.7 kB/s eta 0:00:01
#      --------------------------------     901.1/991.5 kB 243.7 kB/s eta 0:00:01
#      ---------------------------------    911.4/991.5 kB 243.3 kB/s eta 0:00:01
#      ---------------------------------    931.8/991.5 kB 244.8 kB/s eta 0:00:01
#      ----------------------------------   952.3/991.5 kB 247.1 kB/s eta 0:00:01
#      ----------------------------------   952.3/991.5 kB 247.1 kB/s eta 0:00:01
#      ----------------------------------   962.6/991.5 kB 242.8 kB/s eta 0:00:01
#      -----------------------------------  983.0/991.5 kB 245.2 kB/s eta 0:00:01
#      ------------------------------------ 991.5/991.5 kB 245.3 kB/s eta 0:00:00
# Requirement already satisfied: sacremoses in c:\users\mayank\anaconda3\lib\site-packages (from transformers) (0.0.43)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\mayank\anaconda3\lib\site-packages (from boto3->transformers) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\mayank\anaconda3\lib\site-packages (from boto3->transformers) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\mayank\anaconda3\lib\site-packages (from boto3->transformers) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mayank\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayank\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayank\anaconda3\lib\site-packages (from requests->transformers) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayank\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: six in c:\users\mayank\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in c:\users\mayank\anaconda3\lib\site-packages (from sacremoses->transformers) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mayank\anaconda3\lib\site-packages (from sacremoses->transformers) (1.1.1)
# Requirement already satisfied: colorama in c:\users\mayank\anaconda3\lib\site-packages (from tqdm->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\mayank\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3->transformers) (2.8.2)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0

# %%
# Function to translate text from English to Hindi
def translate(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

    # Perform translation and decode the output
    translated = model.generate(**inputs)
    translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)
    return translated_text

# Example usage
english_text = "Lets start about SIH, guys"
hindi_translation = translate(english_text)
print("Hindi Translation:", hindi_translation)
